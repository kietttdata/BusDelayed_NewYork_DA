# %%
#Load pandas and numpy with aliasing
import pandas as pd
import numpy as np
import datetime

# %%
#Reading csv file
final_df=pd.read_csv('/content/drive/MyDrive/bus-breakdowns-delays.csv', low_memory=False)
final_df.head()

# %%
#Check name of column
final_df.columns
#Check column types
final_df.dtypes
# Out:
# School_Year                        object
# Busbreakdown_ID                     int64
# Run_Type                           object
# Bus_No                             object
# Route_Number                       object
# Reason                             object
# Schools_Serviced                   object
# Occurred_On                        object
# Created_On                         object
# Boro                               object
# Bus_Company_Name                   object
# How_Long_Delayed                   object
# Number_Of_Students_On_The_Bus       int64
# Has_Contractor_Notified_Schools    object
# Has_Contractor_Notified_Parents    object
# Have_You_Alerted_OPT               object
# Informed_On                        object
# Incident_Number                    object
# Last_Updated_On                    object
# Breakdown_or_Running_Late          object
# School_Age_or_PreK                 object
# dtype: object

# %%
#check duplicate Breakdown ID
final_df['Busbreakdown_ID'].duplicated().any()
# Out:
# False

# %%
#Check String type
pd.unique(dirty_df['School_Year'])
# Out:
# array(['2015-2016', '2017-2018', '2016-2017', '2018-2019', '2022-2023',
#        '2019-2020', '2021-2022', '2020-2021'], dtype=object)

# %%
pd.unique(dirty_df['Run_Type'])
# Out:
# array(['Special Ed AM Run', 'Pre-K/EI', 'General Ed AM Run',
#        'General Ed Field Trip', 'Special Ed PM Run', 'General Ed PM Run',
#        'Project Read PM Run', 'Special Ed Field Trip',
#        'Project Read AM Run', 'Project Read Field Trip', nan],
#       dtype=object)

# %%
#Check null value with Run_Type column
final_df[(final_df['Run_Type'].isnull())]
# Out:
#        School_Year  Busbreakdown_ID Run_Type  Bus_No Route_Number  \
# 65554    2016-2017          1311159      NaN  NI0649         K022
# 130237   2017-2018          1382111      NaN    1430         M437
# 178090   2015-2016          1273634      NaN     404         P598
# 493618   2021-2022          1703387      NaN    1258         Q141
# 523487   2022-2023          1767897      NaN    4803         K761
# 543552   2022-2023          1778469      NaN    1751         L643
#
#                              Reason         Schools_Serviced  \
# 65554   Late return from Field Trip                    20180
# 130237                Heavy Traffic              05079,05440
# 178090                    Flat Tire                    26704
# 493618                Heavy Traffic                    28010
# 523487                Heavy Traffic        21007,21239,21370
# 543552                Heavy Traffic  15032,15628,15689,15704
#
# ...

# %%
#Sum Null in Run_Type
final_df['Run_Type'].isnull().sum()
# Out:
# 0

# %%
#Removing rows with null in Runtype
final_df.dropna(subset=['Run_Type'], inplace=True)
len(final_df.index)
# Out:
# 545685

# %%
#Check Values in Boro column
pd.unique(final_df['Boro'])
# Out:
# array(['New Jersey', 'Manhattan', 'Bronx', 'Westchester', 'Brooklyn',
#        'Rockland County', 'Nassau County', nan, 'Queens', 'Staten Island',
#        'All Boroughs', 'Connecticut'], dtype=object)

# %%
#Check null(nan) in Boro column
final_df['Boro'].isnull().sum()
# Out:
# 11217

# %%
#Replace the null to values in Boro column
final_df['Boro'].fillna('unspecified', inplace=True)
pd.unique(final_df['Boro'])
# Out:
# array(['New Jersey', 'Manhattan', 'Bronx', 'Westchester', 'Brooklyn',
#        'Rockland County', 'Nassau County', 'unspecified', 'Queens',
#        'Staten Island', 'All Boroughs', 'Connecticut'], dtype=object)

# %%
pd.unique(final_df['Boro'])
# Out:
# array(['New Jersey', 'Manhattan', 'Bronx', 'Westchester', 'Brooklyn',
#        'Rockland County', 'Nassau County', 'unspecified', 'Queens',
#        'Staten Island', 'All Boroughs', 'Connecticut'], dtype=object)

# %%
#Check null data in all file
final_df.isna().any()
#true = null
# Out:
# School_Year                        False
# Busbreakdown_ID                    False
# Run_Type                           False
# Bus_No                              True
# Route_Number                        True
# Reason                              True
# Schools_Serviced                    True
# Occurred_On                        False
# Created_On                         False
# Boro                               False
# Bus_Company_Name                   False
# How_Long_Delayed                    True
# Number_Of_Students_On_The_Bus      False
# Has_Contractor_Notified_Schools    False
# Has_Contractor_Notified_Parents    False
# Have_You_Alerted_OPT               False
# Informed_On                        False
# Incident_Number                     True
# Last_Updated_On                    False
# Breakdown_or_Running_Late          False
# School_Age_or_PreK                 False
# dtype: bool

# %%
#change datatypes to datetime
final_df['Occurred_On']=pd.to_datetime(final_df['Occurred_On'])
final_df['Created_On'] = pd.to_datetime(final_df['Created_On'])
final_df['Informed_On'] = pd.to_datetime(final_df['Informed_On'])
final_df['Last_Updated_On'] = pd.to_datetime(final_df['Last_Updated_On'])

final_df.dtypes
# Out:
# School_Year                                object
# Busbreakdown_ID                             int64
# Run_Type                                   object
# Bus_No                                     object
# Route_Number                               object
# Reason                                     object
# Schools_Serviced                           object
# Occurred_On                        datetime64[ns]
# Created_On                         datetime64[ns]
# Boro                                       object
# Bus_Company_Name                           object
# How_Long_Delayed                           object
# Number_Of_Students_On_The_Bus               int64
# Has_Contractor_Notified_Schools            object
# Has_Contractor_Notified_Parents            object
# Have_You_Alerted_OPT                       object
# Informed_On                        datetime64[ns]
# Incident_Number                            object
# Last_Updated_On                    datetime64[ns]
# ...

# %%
final_df['School_Year'].value_counts()
# Out:
# 2018-2019    109059
# 2021-2022     70179
# 2019-2020     65998
# 2020-2021     20438
# Name: School_Year, dtype: int64

# %%
#Test count rows with the non-use rows
#final_df.drop(["2016-2017","2017-2018","2022-2023"])
df_filter=final_df[final_df['School_Year']=='2016-2017']
print(df_filter.shape)
df_filter2=final_df[final_df['School_Year']=='2017-2018']
print(df_filter2.shape)
df_filter3=final_df[final_df['School_Year']=='2022-2023']
print(df_filter3.shape)
# Out:
# (83141, 21)
# (89435, 21)
# (44257, 21)

# %%
#Remove rows with the non-use rows
final_df=final_df[final_df["School_Year"].str.contains("2015-2016")==False]
final_df=final_df[final_df["School_Year"].str.contains("2016-2017|2017-2018|2022-2023")==False]
final_df.head(-2)
# Out:
#        School_Year  Busbreakdown_ID           Run_Type Bus_No Route_Number  \
# 82       2018-2019          1456627  General Ed AM Run   1141        R1086
# 835      2018-2019          1456628  Special Ed AM Run    87D         X966
# 2238     2018-2019          1456629  Special Ed AM Run   1140         X174
# 3793     2018-2019          1456630  Special Ed AM Run   5591         Q059
# 5001     2018-2019          1456631  Special Ed AM Run   1505         K042
# ...            ...              ...                ...    ...          ...
# 502480   2018-2019          1564211           Pre-K/EI   9061        3112A
# 502481   2018-2019          1564527  Special Ed AM Run  1627D         X750
# 502482   2018-2019          1565307  Special Ed PM Run   1104         M792
# 502483   2018-2019          1565308  Special Ed PM Run    651         L655
# 502484   2018-2019          1565309           Pre-K/EI   9311            8
#
# ...
